# %% [markdown]
# **Image to Pencil Sketch**
#
# Import libraries

# %%
from google.colab.patches import cv2_imshow
import cv2

# %% [markdown]
# Import picture

# %%
img = cv2.imread("demo.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=518x519 at 0x7F2A07F099D0>

# %% [markdown]
# Check for RGB scale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=518x519 at 0x7F2A07F16310>

# %% [markdown]
# Change to Gray Scale

# %%
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=518x519 at 0x7F2A07F16290>

# %% [markdown]
# Invert the gray scaled image and blur it

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=518x519 at 0x7F2A07F231D0>

# %% [markdown]
# Final step : Change it to Pencil Sketch

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=518x519 at 0x7F2A07F23A90>
